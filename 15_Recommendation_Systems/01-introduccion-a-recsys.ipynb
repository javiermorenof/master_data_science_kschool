# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# <img src="kschool.png" width="120" height="120" align="right"/>
#
# # Introducción

# %% [markdown]
# ![imagen.png](attachment:imagen.png)
#
# https://es.wikipedia.org/wiki/Sistema_de_recomendaci%C3%B3n
#
# https://en.wikipedia.org/wiki/Recommender_system

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ### Objetivos:
#
# - Recomendar la items a users
# - Encontrar items similares en función de características propias del item o gustos del user
# - Encontrar users con gustos similares
# - Pseudo-clasificar items o users nuevos en el catálogo

# %% [markdown]
# ### Netflix prize

# %% [markdown]
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ### Tipos
#
# - Content-based Filtering
# - Collaborative Filtering
# - Knowledge-based
# - Reglas de asociación
# - Hybrid models

# %% [markdown]
# ### Librerías que habría que instalar:
#
# - Pyspark
# - Keras de Tensorflow
