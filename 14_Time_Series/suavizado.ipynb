# %% [markdown]
# <a name = "inicio"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use("seaborn")                  # Establecemos el estilo gráfico de seaborn por defecto
plt.rcParams["figure.figsize"] = (15, 5)  # Tamaño por defecto de las gráficas a crear

# %%
candy = pd.read_csv("candy_production.csv", parse_dates = ["observation_date"])
candy.rename({"observation_date": "date", "IPG3113N": "production"}, inplace = True, axis = 1)
candy.set_index("date", inplace = True)
candy.head()
# Out:
#             production
# date
# 1972-01-01     85.6945
# 1972-02-01     71.8200
# 1972-03-01     66.0229
# 1972-04-01     64.5645
# 1972-05-01     65.0100

# %% [markdown]
# Para simplificar el gráfico, nos quedamos con datos posteriores a 2009

# %%
candy = candy.truncate(before = "2010")

# %%
candy.plot()
plt.suptitle("Datos originales", fontsize = 20)
plt.show()

# %% [markdown]
# # rolling window

# %%
candy_roll = candy.rolling(window = 10, min_periods = 1).mean()

# %%
candy_roll.plot()
plt.suptitle("Datos suavizados con una rolling window", fontsize = 20)
plt.show()

# %% [markdown]
# # resample

# %%
candy_res = candy.resample("3M").mean()

# %%
candy_res.plot()
plt.suptitle("Datos suavizados tras remuestrear los datos", fontsize = 20)
plt.show()
